# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df_1 = pd.read_csv('data/export_20feb_20_23pm_full_update.csv')
df_1.head()
# Out:
#    Unnamed: 0    SDATEHOUR    SITE_NAME NETWORK_TYPE AREA AREA_TYPE AREA2  \
# 0           0  20200220 07  OTR0374L_C1       eUTRAN  OTR       B66  East
# 1           1  20200220 07  OTR0646L_C1       eUTRAN  OTR       B66  East
# 2           2  20200220 07  OTR0646L_C1       eUTRAN  OTR       B66  East
# 3           3  20200220 07  OTR0511L_B1       eUTRAN  OTR       B66  East
# 4           4  20200220 07  OOT0063L_A1       eUTRAN  OOT        B4  East
#
#      AREA3  LONGITUDE   LATITUDE  ... UL_PKT_COUNT_ALL UL_PKT_LOST_COUNT_ALL  \
# 0  Toronto -79.231896  43.780936  ...                0                     0
# 1  Toronto -79.752588  43.663444  ...                0                     0
# 2  Toronto -79.752588  43.663444  ...              725                     5
# 3  Toronto -79.723706  43.664807  ...                0                     0
# 4   Ottawa -75.803776  45.332680  ...                0                     0
#
#   UL_PAYLOAD_DATA_TOTAL_SIZE  UL_PAYLOAD_DATA_SIZE  DL_PKT_COUNT_ALL  \
# 0                          0                     0                 0
# 1                          0                     0                 0
# 2                      55751                 51417               606
# 3                          0                     0                 0
# 4                          0                     0                 0
#
#    DL_PKT_LOST_COUNT_ALL  DL_PAYLOAD_DATA_TOTAL_SIZE  DL_PAYLOAD_DATA_SIZE  \
# 0                      0                           0                     0
# 1                      0                           0                     0
# 2                      0                       46547                 39593
# 3                      0                           0                     0
# 4                      0                           0                     0
#
#    DIR  CODEC_RATE
# 0    2       12650
# 1    1       12650
# 2    1       12650
# 3    1       12200
# 4    1       23850
#
# [5 rows x 51 columns]

# %%
df_1 = df_1.drop(['CI'], axis=1)

# %%
df_1.head()
# Out:
#      SDATEHOUR    SITE_NAME NETWORK_TYPE AREA AREA_TYPE AREA2    AREA3  \
# 0  20200220 07  OTR0374L_C1       eUTRAN  OTR       B66  East  Toronto
# 1  20200220 07  OTR0646L_C1       eUTRAN  OTR       B66  East  Toronto
# 2  20200220 07  OTR0646L_C1       eUTRAN  OTR       B66  East  Toronto
# 3  20200220 07  OTR0511L_B1       eUTRAN  OTR       B66  East  Toronto
# 4  20200220 07  OOT0063L_A1       eUTRAN  OOT        B4  East   Ottawa
#
#    LONGITUDE   LATITUDE IPADD_DOTNUMFORMAT(SGW_IP)  ... UL_PKT_COUNT_ALL  \
# 0 -79.231896  43.780936              74.115.197.18  ...                0
# 1 -79.752588  43.663444              74.115.197.17  ...                0
# 2 -79.752588  43.663444              74.115.197.17  ...              725
# 3 -79.723706  43.664807              74.115.197.16  ...                0
# 4 -75.803776  45.332680              74.115.197.16  ...                0
#
#   UL_PKT_LOST_COUNT_ALL  UL_PAYLOAD_DATA_TOTAL_SIZE  UL_PAYLOAD_DATA_SIZE  \
# 0                     0                           0                     0
# 1                     0                           0                     0
# 2                     5                       55751                 51417
# 3                     0                           0                     0
# 4                     0                           0                     0
#
#    DL_PKT_COUNT_ALL  DL_PKT_LOST_COUNT_ALL  DL_PAYLOAD_DATA_TOTAL_SIZE  \
# 0                 0                      0                           0
# 1                 0                      0                           0
# 2               606                      0                       46547
# 3                 0                      0                           0
# 4                 0                      0                           0
#
#    DL_PAYLOAD_DATA_SIZE  DIR  CODEC_RATE
# 0                     0    2       12650
# 1                     0    1       12650
# 2                 39593    1       12650
# 3                     0    1       12200
# 4                     0    1       23850
#
# [5 rows x 50 columns]

# %%
df_1.to_csv(r'data/export_20feb_20_23pm_full_update.csv')

# %%
df_1.head()
# Out:
#      SDATEHOUR    SITE_NAME NETWORK_TYPE AREA AREA_TYPE AREA2    AREA3  \
# 0  20200220 07  OTR0374L_C1       eUTRAN  OTR       B66  East  Toronto
# 1  20200220 07  OTR0646L_C1       eUTRAN  OTR       B66  East  Toronto
# 2  20200220 07  OTR0646L_C1       eUTRAN  OTR       B66  East  Toronto
# 3  20200220 07  OTR0511L_B1       eUTRAN  OTR       B66  East  Toronto
# 4  20200220 07  OOT0063L_A1       eUTRAN  OOT        B4  East   Ottawa
#
#    LONGITUDE   LATITUDE IPADD_DOTNUMFORMAT(SGW_IP)  ... UL_PKT_COUNT_ALL  \
# 0 -79.231896  43.780936              74.115.197.18  ...                0
# 1 -79.752588  43.663444              74.115.197.17  ...                0
# 2 -79.752588  43.663444              74.115.197.17  ...              725
# 3 -79.723706  43.664807              74.115.197.16  ...                0
# 4 -75.803776  45.332680              74.115.197.16  ...                0
#
#   UL_PKT_LOST_COUNT_ALL  UL_PAYLOAD_DATA_TOTAL_SIZE  UL_PAYLOAD_DATA_SIZE  \
# 0                     0                           0                     0
# 1                     0                           0                     0
# 2                     5                       55751                 51417
# 3                     0                           0                     0
# 4                     0                           0                     0
#
#    DL_PKT_COUNT_ALL  DL_PKT_LOST_COUNT_ALL  DL_PAYLOAD_DATA_TOTAL_SIZE  \
# 0                 0                      0                           0
# 1                 0                      0                           0
# 2               606                      0                       46547
# 3                 0                      0                           0
# 4                 0                      0                           0
#
#    DL_PAYLOAD_DATA_SIZE  DIR  CODEC_RATE
# 0                     0    2       12650
# 1                     0    1       12650
# 2                 39593    1       12650
# 3                     0    1       12200
# 4                     0    1       23850
#
# [5 rows x 50 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
from shapely.geometry import Point
import os
 
#making point shapefile
binpath_b = '/Users/ihasan/Downloads/Blogging/Mapping in python with geopandas/'
fn_b = os.path.join(binpath_b,'point_inf.csv')
df = pd.read_csv(fn_b)
df['Coordinates'] = list(zip(df.Long, df.Lat))
df['Coordinates'] = df['Coordinates'].apply(Point)
sites = gpd.GeoDataFrame(df, geometry='Coordinates')
sites.plot() #This will plots the points

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-db2649dcf0a1> in <module>()
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 from mpl_toolkits.basemap import Basemap
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in <module>()
#     153
#     154 # create dictionary that maps epsg codes to Basemap kwargs.
# --> 155 pyproj_datadir = os.environ['PROJ_LIB']
#     156 epsgf = open(os.path.join(pyproj_datadir,'epsg'))
#     157 epsg_dict={}
#
# ~\AppData\Local\Continuum\anaconda3\lib\os.py in __getitem__(self, key)
#     667         except KeyError:
#     668             # raise KeyError with the original key value
# --> 669             raise KeyError(key) from None
#     670         return self.decodevalue(value)
#     671
#
# KeyError: 'PROJ_LIB'
